# %% [markdown]
# # EDA on trafiklab resrobot API

# %%
from dotenv import load_dotenv
import os 
import requests

load_dotenv()

API_KEY = os.getenv("API_KEY")

url = f"https://api.resrobot.se/v2.1/trip?format=json&originId=740000002&destId=740000003&passlist=true&showPassingPoints=true&accessId={API_KEY}"

response = requests.get(url)

result = response.json()
result.keys()
# Out:
# dict_keys(['Trip', 'ResultStatus', 'TechnicalMessages', 'serverVersion', 'dialectVersion', 'planRtTs', 'requestId', 'scrB', 'scrF'])

# %%
len(result["Trip"])
# Out:
# 5

# %%
result["ResultStatus"], result["TechnicalMessages"], result["planRtTs"], result["scrB"]
# Out:
# ({'timeDiffCritical': False},
#  {'TechnicalMessage': [{'value': '2025-01-07 11:07:11', 'key': 'requestTime'},
#    {'value': 'ttp=16417#16603 plancode0=zzlri planid=1736224604 planid0=1736224604 planid_adr=1479298166 plancode_adr=q0r10 srvv=5.45.SAMTRAFIKEN.15.0.1 (customer/hcusamtrafiken/release/2023.10.0) [2023-10-19] tlibv=TRFVER: rel/pproxy/4.00.0 2022-10-24 18:24:51 +0200 Relay_EnrichmentProxy v1 jno=1',
#     'key': 'backendInfo'}]},
#  '1970-01-01T01:00:00.000+01:00',
#  '3|OB|MTµ14µ42460µ42460µ42648µ42648µ0µ0µ365µ42427µ1µ0µ1122µ0µ0µ-2147483648µ1µ2|PDHµ378355956619a5b7de5fd8151f63f427|RDµ7012025|RTµ110711|USµ1|RSµINIT')

# %%
example_trip = result["Trip"][0]
example_trip.keys()
# Out:
# dict_keys(['Origin', 'Destination', 'ServiceDays', 'LegList', 'calculation', 'TripStatus', 'idx', 'tripId', 'ctxRecon', 'duration', 'rtDuration', 'checksum'])

# %%
example_trip["Origin"]
# Out:
# {'name': 'Göteborg Centralstation',
#  'type': 'ST',
#  'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#  'extId': '740000002',
#  'lon': 11.973479,
#  'lat': 57.708895,
#  'routeIdx': 0,
#  'prognosisType': 'PROGNOSED',
#  'time': '11:40:00',
#  'date': '2025-01-07',
#  'minimumChangeDuration': 'PT15M'}

# %%
example_trip["Destination"]
# Out:
# {'name': 'Malmö Centralstation',
#  'type': 'ST',
#  'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#  'extId': '740000003',
#  'lon': 13.00091,
#  'lat': 55.609456,
#  'routeIdx': 12,
#  'prognosisType': 'PROGNOSED',
#  'time': '14:48:00',
#  'date': '2025-01-07',
#  'minimumChangeDuration': 'PT15M'}

# %%
example_trip["LegList"]["Leg"][0].keys()
# Out:
# dict_keys(['Origin', 'Destination', 'Notes', 'JourneyDetailRef', 'JourneyStatus', 'Product', 'Stops', 'JourneyDetail', 'id', 'idx', 'name', 'number', 'category', 'type', 'reachable', 'waitingState', 'direction', 'directionFlag', 'duration'])

# %%
stops = example_trip["LegList"]["Leg"][0]["Stops"]["Stop"]
stops
# Out:
# [{'name': 'Göteborg Centralstation',
#   'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#   'extId': '740000002',
#   'routeIdx': 0,
#   'lon': 11.973479,
#   'lat': 57.708895,
#   'depPrognosisType': 'PROGNOSED',
#   'depTime': '11:40:00',
#   'depDate': '2025-01-07',
#   'depDir': 'Köpenhamn Österport (Danmark)',
#   'minimumChangeDuration': 'PT15M'},
#  {'name': 'Mölndal station',
#   'id': 'A=1@O=Mölndal station@X=12018722@Y=57655958@U=1@L=740000315@',
#   'extId': '740000315',
#   'routeIdx': 1,
#   'lon': 12.018722,
#   'lat': 57.655958,
#   'depTime': '11:48:00',
#   'depDate': '2025-01-07',
#   'arrTime': '11:48:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT9M'},
#  {'name': 'Kungsbacka station',
#   'id': 'A=1@O=Kungsbacka station@X=12079614@Y=57490556@U=1@L=740000161@',
#   'extId': '740000161',
#   'routeIdx': 2,
#   'lon': 12.079614,
#   'lat': 57.490556,
#   'depTime': '11:59:00',
#   'depDate': '2025-01-07',
#   'arrTime': '11:59:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT5M'},
#  {'name': 'Varberg station',
#   'id': 'A=1@O=Varberg station@X=12248081@Y=57109378@U=1@L=740000110@',
#   'extId': '740000110',
#   'routeIdx': 3,
#   'lon': 12.248081,
#   'lat': 57.109378,
#   'depTime': '12:29:00',
#   'depDate': '2025-01-07',
#   'arrTime': '12:25:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT5M'},
#  {'name': 'Falkenberg station',
#   'id': 'A=1@O=Falkenberg station@X=12507555@Y=56919768@U=1@L=740001579@',
#   'extId': '740001579',
#   'routeIdx': 4,
#   'lon': 12.507555,
#   'lat': 56.919768,
#   'depTime': '12:45:00',
#   'depDate': '2025-01-07',
#   'arrTime': '12:45:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT4M'},
#  {'name': 'Halmstad Centralstation',
#   'id': 'A=1@O=Halmstad Centralstation@X=12864840@Y=56669275@U=1@L=740000080@',
#   'extId': '740000080',
#   'routeIdx': 5,
#   'lon': 12.86484,
#   'lat': 56.669275,
#   'depTime': '13:13:00',
#   'depDate': '2025-01-07',
#   'arrTime': '13:03:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Laholm station',
#   'id': 'A=1@O=Laholm station@X=12999606@Y=56501905@U=1@L=740000058@',
#   'extId': '740000058',
#   'routeIdx': 6,
#   'lon': 12.999606,
#   'lat': 56.501905,
#   'depTime': '13:25:00',
#   'depDate': '2025-01-07',
#   'arrTime': '13:25:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT9M'},
#  {'name': 'Båstad station',
#   'id': 'A=1@O=Båstad station@X=12906991@Y=56431834@U=1@L=740001603@',
#   'extId': '740001603',
#   'routeIdx': 7,
#   'lon': 12.906991,
#   'lat': 56.431834,
#   'depTime': '13:32:00',
#   'depDate': '2025-01-07',
#   'arrTime': '13:32:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT4M'},
#  {'name': 'Ängelholm station',
#   'id': 'A=1@O=Ängelholm station@X=12854197@Y=56245200@U=1@L=740000064@',
#   'extId': '740000064',
#   'routeIdx': 8,
#   'lon': 12.854197,
#   'lat': 56.2452,
#   'depTime': '13:43:00',
#   'depDate': '2025-01-07',
#   'arrTime': '13:43:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Helsingborg Centralstation',
#   'id': 'A=1@O=Helsingborg Centralstation@X=12694261@Y=56044408@U=1@L=740000044@',
#   'extId': '740000044',
#   'routeIdx': 9,
#   'lon': 12.694261,
#   'lat': 56.044408,
#   'depTime': '14:07:00',
#   'depDate': '2025-01-07',
#   'arrTime': '14:04:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT9M'},
#  {'name': 'Landskrona station',
#   'id': 'A=1@O=Landskrona station@X=12857406@Y=55878898@U=1@L=740001554@',
#   'extId': '740001554',
#   'routeIdx': 10,
#   'lon': 12.857406,
#   'lat': 55.878898,
#   'depTime': '14:19:00',
#   'depDate': '2025-01-07',
#   'arrTime': '14:19:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT9M'},
#  {'name': 'Lund Centralstation',
#   'id': 'A=1@O=Lund Centralstation@X=13186897@Y=55708094@U=1@L=740000120@',
#   'extId': '740000120',
#   'routeIdx': 11,
#   'lon': 13.186897,
#   'lat': 55.708094,
#   'depTime': '14:38:00',
#   'depDate': '2025-01-07',
#   'arrTime': '14:36:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Malmö Centralstation',
#   'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#   'extId': '740000003',
#   'routeIdx': 12,
#   'lon': 13.00091,
#   'lat': 55.609456,
#   'arrTime': '14:48:00',
#   'arrDate': '2025-01-07',
#   'minimumChangeDuration': 'PT15M'}]

# %%
for stop in stops: 
    print(f"{stop['name']} {stop.get('arrTime')}")
# Out:
# Göteborg Centralstation None
# Mölndal station 11:48:00
# Kungsbacka station 11:59:00
# Varberg station 12:25:00
# Falkenberg station 12:45:00
# Halmstad Centralstation 13:03:00
# Laholm station 13:25:00
# Båstad station 13:32:00
# Ängelholm station 13:43:00
# Helsingborg Centralstation 14:04:00
# Landskrona station 14:19:00
# Lund Centralstation 14:36:00
# Malmö Centralstation 14:48:00

# %% [markdown]
# ## Stop lookup

# %%
location = "tranered"

def get_location_id(location): 
    url = f"https://api.resrobot.se/v2.1/location.name?input={location}&format=json&accessId={API_KEY}"
    result = requests.get(url)
    return result.json().get("stopLocationOrCoordLocation")

tranered = get_location_id("tranered")
len(tranered)
# Out:
# 10

# %%
tranered[0].get("StopLocation")
# Out:
# {'productAtStop': [{'icon': {'res': 'prod_gen'}, 'cls': '64'},
#   {'icon': {'res': 'prod_gen'}, 'cls': '128'}],
#  'timezoneOffset': 60,
#  'id': 'A=1@O=Göteborg Tranered@X=11879631@Y=57672516@U=1@L=740025725@B=1@p=1736224604@',
#  'extId': '740025725',
#  'name': 'Göteborg Tranered',
#  'lon': 11.879631,
#  'lat': 57.672516,
#  'weight': 1931,
#  'products': 192,
#  'minimumChangeDuration': 'PT0S'}

# %%
location_id = 740025725
url = f"https://api.resrobot.se/v2.1/departureBoard?id={location_id}&format=json&accessId={API_KEY}"
response = requests.get(url)
response.json()["Departure"]
# Out:
# [{'JourneyDetailRef': {'ref': '1|167701|28|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 11',
#    'internalName': 'Länstrafik - Spårväg 11',
#    'displayNumber': '11',
#    'num': '11',
#    'line': '11',
#    'lineId': '1279501100001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '11;5011;4947'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 11',
#     'internalName': 'Länstrafik - Spårväg 11',
#     'displayNumber': '11',
#     'num': '11',
#     'line': '11',
#     'lineId': '1279501100001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 4,
#     'routeIdxTo': 34,
#     'matchId': '11;5011;4947'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 4,
#      'routeIdxTo': 34,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 11',
#   'type': 'ST',
#   'stop': 'Göteborg Tranered',
#   'stopid': 'A=1@O=Göteborg Tranered@X=11879631@Y=57672516@U=1@L=740025725@',
#   'stopExtId': '740025725',
#   'lon': 11.879631,
#   'lat': 57.672516,
#   'time': '11:44:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Bergsjön Komettorget (Göteborg kn)',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|168013|16|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 11',
#    'internalName': 'Länstrafik - Spårväg 11',
#    'displayNumber': '11',
#    'num': '11',
#    'line': '11',
#    'lineId': '1279501100001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '11;5011;4888'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 11',
#     'internalName': 'Länstrafik - Spårväg 11',
#     'displayNumber': '11',
#     'num': '11',
#     'line': '11',
#     'lineId': '1279501100001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 30,
#     'routeIdxTo': 34,
#     'matchId': '11;5011;4888'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 30,
#      'routeIdxTo': 34,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 11',
#   'type': 'ST',
#   'stop': 'Göteborg Tranered',
#   'stopid': 'A=1@O=Göteborg Tranered@X=11879631@Y=57672516@U=1@L=740025725@',
#   'stopExtId': '740025725',
#   'lon': 11.879631,
#   'lat': 57.672516,
#   'time': '11:46:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Göteborg Saltholmens Brygga',
#   'directionFlag': '2'},
#  {'JourneyDetailRef': {'ref': '1|167701|29|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 11',
#    'internalName': 'Länstrafik - Spårväg 11',
#    'displayNumber': '11',
#    'num': '11',
#    'line': '11',
#    'lineId': '1279501100001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '11;5011;4969'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 11',
#     'internalName': 'Länstrafik - Spårväg 11',
#     'displayNumber': '11',
#     'num': '11',
#     'line': '11',
#     'lineId': '1279501100001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 4,
#     'routeIdxTo': 34,
#     'matchId': '11;5011;4969'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 4,
#      'routeIdxTo': 34,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 11',
#   'type': 'ST',
#   'stop': 'Göteborg Tranered',
#   'stopid': 'A=1@O=Göteborg Tranered@X=11879631@Y=57672516@U=1@L=740025725@',
#   'stopExtId': '740025725',
#   'lon': 11.879631,
#   'lat': 57.672516,
#   'time': '11:54:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Bergsjön Komettorget (Göteborg kn)',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|168013|17|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 11',
#    'internalName': 'Länstrafik - Spårväg 11',
#    'displayNumber': '11',
#    'num': '11',
#    'line': '11',
#    'lineId': '1279501100001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '11;5011;4910'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 11',
#     'internalName': 'Länstrafik - Spårväg 11',
#     'displayNumber': '11',
#     'num': '11',
#     'line': '11',
#     'lineId': '1279501100001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 30,
#     'routeIdxTo': 34,
#     'matchId': '11;5011;4910'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 30,
#      'routeIdxTo': 34,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 11',
#   'type': 'ST',
#   'stop': 'Göteborg Tranered',
#   'stopid': 'A=1@O=Göteborg Tranered@X=11879631@Y=57672516@U=1@L=740025725@',
#   'stopExtId': '740025725',
#   'lon': 11.879631,
#   'lat': 57.672516,
#   'time': '11:56:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Göteborg Saltholmens Brygga',
#   'directionFlag': '2'},
#  {'JourneyDetailRef': {'ref': '1|167701|30|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 11',
#    'internalName': 'Länstrafik - Spårväg 11',
#    'displayNumber': '11',
#    'num': '11',
#    'line': '11',
#    'lineId': '1279501100001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '11;5011;4991'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 11',
#     'internalName': 'Länstrafik - Spårväg 11',
#     'displayNumber': '11',
#     'num': '11',
#     'line': '11',
#     'lineId': '1279501100001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 4,
#     'routeIdxTo': 34,
#     'matchId': '11;5011;4991'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 4,
#      'routeIdxTo': 34,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 11',
#   'type': 'ST',
#   'stop': 'Göteborg Tranered',
#   'stopid': 'A=1@O=Göteborg Tranered@X=11879631@Y=57672516@U=1@L=740025725@',
#   'stopExtId': '740025725',
#   'lon': 11.879631,
#   'lat': 57.672516,
#   'time': '12:04:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Bergsjön Komettorget (Göteborg kn)',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|168013|18|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 11',
#    'internalName': 'Länstrafik - Spårväg 11',
#    'displayNumber': '11',
#    'num': '11',
#    'line': '11',
#    'lineId': '1279501100001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '11;5011;4932'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 11',
#     'internalName': 'Länstrafik - Spårväg 11',
#     'displayNumber': '11',
#     'num': '11',
#     'line': '11',
#     'lineId': '1279501100001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 30,
#     'routeIdxTo': 34,
#     'matchId': '11;5011;4932'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 30,
#      'routeIdxTo': 34,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 11',
#   'type': 'ST',
#   'stop': 'Göteborg Tranered',
#   'stopid': 'A=1@O=Göteborg Tranered@X=11879631@Y=57672516@U=1@L=740025725@',
#   'stopExtId': '740025725',
#   'lon': 11.879631,
#   'lat': 57.672516,
#   'time': '12:06:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Göteborg Saltholmens Brygga',
#   'directionFlag': '2'},
#  {'JourneyDetailRef': {'ref': '1|167701|31|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 11',
#    'internalName': 'Länstrafik - Spårväg 11',
#    'displayNumber': '11',
#    'num': '11',
#    'line': '11',
#    'lineId': '1279501100001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '11;5011;5013'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 11',
#     'internalName': 'Länstrafik - Spårväg 11',
#     'displayNumber': '11',
#     'num': '11',
#     'line': '11',
#     'lineId': '1279501100001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 4,
#     'routeIdxTo': 34,
#     'matchId': '11;5011;5013'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 4,
#      'routeIdxTo': 34,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 11',
#   'type': 'ST',
#   'stop': 'Göteborg Tranered',
#   'stopid': 'A=1@O=Göteborg Tranered@X=11879631@Y=57672516@U=1@L=740025725@',
#   'stopExtId': '740025725',
#   'lon': 11.879631,
#   'lat': 57.672516,
#   'time': '12:14:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Bergsjön Komettorget (Göteborg kn)',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|168013|19|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 11',
#    'internalName': 'Länstrafik - Spårväg 11',
#    'displayNumber': '11',
#    'num': '11',
#    'line': '11',
#    'lineId': '1279501100001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '11;5011;4954'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 11',
#     'internalName': 'Länstrafik - Spårväg 11',
#     'displayNumber': '11',
#     'num': '11',
#     'line': '11',
#     'lineId': '1279501100001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 30,
#     'routeIdxTo': 34,
#     'matchId': '11;5011;4954'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 30,
#      'routeIdxTo': 34,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 11',
#   'type': 'ST',
#   'stop': 'Göteborg Tranered',
#   'stopid': 'A=1@O=Göteborg Tranered@X=11879631@Y=57672516@U=1@L=740025725@',
#   'stopExtId': '740025725',
#   'lon': 11.879631,
#   'lat': 57.672516,
#   'time': '12:16:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Göteborg Saltholmens Brygga',
#   'directionFlag': '2'},
#  {'JourneyDetailRef': {'ref': '1|167701|32|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 11',
#    'internalName': 'Länstrafik - Spårväg 11',
#    'displayNumber': '11',
#    'num': '11',
#    'line': '11',
#    'lineId': '1279501100001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '11;5011;5035'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 11',
#     'internalName': 'Länstrafik - Spårväg 11',
#     'displayNumber': '11',
#     'num': '11',
#     'line': '11',
#     'lineId': '1279501100001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 4,
#     'routeIdxTo': 34,
#     'matchId': '11;5011;5035'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 4,
#      'routeIdxTo': 34,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 11',
#   'type': 'ST',
#   'stop': 'Göteborg Tranered',
#   'stopid': 'A=1@O=Göteborg Tranered@X=11879631@Y=57672516@U=1@L=740025725@',
#   'stopExtId': '740025725',
#   'lon': 11.879631,
#   'lat': 57.672516,
#   'time': '12:24:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Bergsjön Komettorget (Göteborg kn)',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|168013|20|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 11',
#    'internalName': 'Länstrafik - Spårväg 11',
#    'displayNumber': '11',
#    'num': '11',
#    'line': '11',
#    'lineId': '1279501100001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '11;5011;4976'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 11',
#     'internalName': 'Länstrafik - Spårväg 11',
#     'displayNumber': '11',
#     'num': '11',
#     'line': '11',
#     'lineId': '1279501100001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 30,
#     'routeIdxTo': 34,
#     'matchId': '11;5011;4976'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 30,
#      'routeIdxTo': 34,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 11',
#   'type': 'ST',
#   'stop': 'Göteborg Tranered',
#   'stopid': 'A=1@O=Göteborg Tranered@X=11879631@Y=57672516@U=1@L=740025725@',
#   'stopExtId': '740025725',
#   'lon': 11.879631,
#   'lat': 57.672516,
#   'time': '12:26:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Göteborg Saltholmens Brygga',
#   'directionFlag': '2'},
#  {'JourneyDetailRef': {'ref': '1|167701|33|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 11',
#    'internalName': 'Länstrafik - Spårväg 11',
#    'displayNumber': '11',
#    'num': '11',
#    'line': '11',
#    'lineId': '1279501100001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '11;5011;5057'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 11',
#     'internalName': 'Länstrafik - Spårväg 11',
#     'displayNumber': '11',
#     'num': '11',
#     'line': '11',
#     'lineId': '1279501100001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 4,
#     'routeIdxTo': 34,
#     'matchId': '11;5011;5057'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 4,
#      'routeIdxTo': 34,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 11',
#   'type': 'ST',
#   'stop': 'Göteborg Tranered',
#   'stopid': 'A=1@O=Göteborg Tranered@X=11879631@Y=57672516@U=1@L=740025725@',
#   'stopExtId': '740025725',
#   'lon': 11.879631,
#   'lat': 57.672516,
#   'time': '12:34:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Bergsjön Komettorget (Göteborg kn)',
#   'directionFlag': '1'},
#  {'JourneyDetailRef': {'ref': '1|168013|21|1|7012025'},
#   'JourneyStatus': 'P',
#   'ProductAtStop': {'icon': {'res': 'prod_gen'},
#    'operatorInfo': {'name': 'Västtrafik',
#     'nameS': '279',
#     'nameN': '279',
#     'nameL': 'Västtrafik',
#     'id': '279'},
#    'name': 'Länstrafik - Spårväg 11',
#    'internalName': 'Länstrafik - Spårväg 11',
#    'displayNumber': '11',
#    'num': '11',
#    'line': '11',
#    'lineId': '1279501100001',
#    'catOut': 'SLT',
#    'catIn': 'SLT',
#    'catCode': '6',
#    'cls': '64',
#    'catOutS': 'SLT',
#    'catOutL': 'Länstrafik - Spårväg',
#    'operatorCode': '279',
#    'operator': 'Västtrafik',
#    'admin': '279___',
#    'matchId': '11;5011;4998'},
#   'Product': [{'icon': {'res': 'prod_gen'},
#     'operatorInfo': {'name': 'Västtrafik',
#      'nameS': '279',
#      'nameN': '279',
#      'nameL': 'Västtrafik',
#      'id': '279'},
#     'name': 'Länstrafik - Spårväg 11',
#     'internalName': 'Länstrafik - Spårväg 11',
#     'displayNumber': '11',
#     'num': '11',
#     'line': '11',
#     'lineId': '1279501100001',
#     'catOut': 'SLT',
#     'catIn': 'SLT',
#     'catCode': '6',
#     'cls': '64',
#     'catOutS': 'SLT',
#     'catOutL': 'Länstrafik - Spårväg',
#     'operatorCode': '279',
#     'operator': 'Västtrafik',
#     'admin': '279___',
#     'routeIdxFrom': 30,
#     'routeIdxTo': 34,
#     'matchId': '11;5011;4998'}],
#   'Notes': {'Note': [{'value': 'Lag 2015:953 tillämpas',
#      'key': 'EG',
#      'type': 'A',
#      'routeIdxFrom': 30,
#      'routeIdxTo': 34,
#      'txtN': 'Lag 2015:953 tillämpas'}]},
#   'name': 'Länstrafik - Spårväg 11',
#   'type': 'ST',
#   'stop': 'Göteborg Tranered',
#   'stopid': 'A=1@O=Göteborg Tranered@X=11879631@Y=57672516@U=1@L=740025725@',
#   'stopExtId': '740025725',
#   'lon': 11.879631,
#   'lat': 57.672516,
#   'time': '12:36:00',
#   'date': '2025-01-07',
#   'reachable': True,
#   'direction': 'Göteborg Saltholmens Brygga',
#   'directionFlag': '2'}]

# %%
import pandas as pd 

pd.DataFrame(response.json()["Departure"])
# Out:
#                     JourneyDetailRef JourneyStatus  \
# 0   {'ref': '1|167701|28|1|7012025'}             P
# 1   {'ref': '1|168013|16|1|7012025'}             P
# 2   {'ref': '1|167701|29|1|7012025'}             P
# 3   {'ref': '1|168013|17|1|7012025'}             P
# 4   {'ref': '1|167701|30|1|7012025'}             P
# 5   {'ref': '1|168013|18|1|7012025'}             P
# 6   {'ref': '1|167701|31|1|7012025'}             P
# 7   {'ref': '1|168013|19|1|7012025'}             P
# 8   {'ref': '1|167701|32|1|7012025'}             P
# 9   {'ref': '1|168013|20|1|7012025'}             P
# 10  {'ref': '1|167701|33|1|7012025'}             P
# 11  {'ref': '1|168013|21|1|7012025'}             P
#
#                                         ProductAtStop  \
# 0   {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 1   {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 2   {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 3   {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 4   {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 5   {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 6   {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 7   {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 8   {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 9   {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 10  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 11  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
#
#                                               Product  \
# 0   [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 1   [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 2   [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 3   [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 4   [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 5   [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 6   [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 7   [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 8   [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 9   [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 10  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 11  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
#
#                                                 Notes  \
# 0   {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
# 1   {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
# 2   {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
# 3   {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
# 4   {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
# 5   {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
# 6   {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
# 7   {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
# 8   {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
# 9   {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
# 10  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
# 11  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...
#
#                        name type               stop  \
# 0   Länstrafik - Spårväg 11   ST  Göteborg Tranered
# 1   Länstrafik - Spårväg 11   ST  Göteborg Tranered
# 2   Länstrafik - Spårväg 11   ST  Göteborg Tranered
# 3   Länstrafik - Spårväg 11   ST  Göteborg Tranered
# 4   Länstrafik - Spårväg 11   ST  Göteborg Tranered
# 5   Länstrafik - Spårväg 11   ST  Göteborg Tranered
# 6   Länstrafik - Spårväg 11   ST  Göteborg Tranered
# 7   Länstrafik - Spårväg 11   ST  Göteborg Tranered
# 8   Länstrafik - Spårväg 11   ST  Göteborg Tranered
# 9   Länstrafik - Spårväg 11   ST  Göteborg Tranered
# 10  Länstrafik - Spårväg 11   ST  Göteborg Tranered
# 11  Länstrafik - Spårväg 11   ST  Göteborg Tranered
#
#                                                stopid  stopExtId        lon  \
# 0   A=1@O=Göteborg Tranered@X=11879631@Y=57672516@...  740025725  11.879631
# 1   A=1@O=Göteborg Tranered@X=11879631@Y=57672516@...  740025725  11.879631
# 2   A=1@O=Göteborg Tranered@X=11879631@Y=57672516@...  740025725  11.879631
# 3   A=1@O=Göteborg Tranered@X=11879631@Y=57672516@...  740025725  11.879631
# 4   A=1@O=Göteborg Tranered@X=11879631@Y=57672516@...  740025725  11.879631
# 5   A=1@O=Göteborg Tranered@X=11879631@Y=57672516@...  740025725  11.879631
# 6   A=1@O=Göteborg Tranered@X=11879631@Y=57672516@...  740025725  11.879631
# 7   A=1@O=Göteborg Tranered@X=11879631@Y=57672516@...  740025725  11.879631
# 8   A=1@O=Göteborg Tranered@X=11879631@Y=57672516@...  740025725  11.879631
# 9   A=1@O=Göteborg Tranered@X=11879631@Y=57672516@...  740025725  11.879631
# 10  A=1@O=Göteborg Tranered@X=11879631@Y=57672516@...  740025725  11.879631
# 11  A=1@O=Göteborg Tranered@X=11879631@Y=57672516@...  740025725  11.879631
#
#           lat      time        date  reachable  \
# 0   57.672516  11:44:00  2025-01-07       True
# 1   57.672516  11:46:00  2025-01-07       True
# 2   57.672516  11:54:00  2025-01-07       True
# 3   57.672516  11:56:00  2025-01-07       True
# 4   57.672516  12:04:00  2025-01-07       True
# 5   57.672516  12:06:00  2025-01-07       True
# 6   57.672516  12:14:00  2025-01-07       True
# 7   57.672516  12:16:00  2025-01-07       True
# 8   57.672516  12:24:00  2025-01-07       True
# 9   57.672516  12:26:00  2025-01-07       True
# 10  57.672516  12:34:00  2025-01-07       True
# 11  57.672516  12:36:00  2025-01-07       True
#
#                              direction directionFlag
# 0   Bergsjön Komettorget (Göteborg kn)             1
# 1          Göteborg Saltholmens Brygga             2
# 2   Bergsjön Komettorget (Göteborg kn)             1
# 3          Göteborg Saltholmens Brygga             2
# 4   Bergsjön Komettorget (Göteborg kn)             1
# 5          Göteborg Saltholmens Brygga             2
# 6   Bergsjön Komettorget (Göteborg kn)             1
# 7          Göteborg Saltholmens Brygga             2
# 8   Bergsjön Komettorget (Göteborg kn)             1
# 9          Göteborg Saltholmens Brygga             2
# 10  Bergsjön Komettorget (Göteborg kn)             1
# 11         Göteborg Saltholmens Brygga             2
